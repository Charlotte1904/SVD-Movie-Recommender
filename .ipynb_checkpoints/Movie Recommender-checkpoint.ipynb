# %%
# %pylab inline

import pandas as pd
import numpy as np
from numpy import linalg as LA
import scipy.sparse as ssp
from scipy.sparse import csr_matrix
from scipy.sparse import csc_matrix
from sparsesvd import sparsesvd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from recommender import MovieRecommender
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b67cb706e375> in <module>()
# ----> 1 from recommender import MovieRecommender
#
# /Users/Charlotte/SVD-MovieRecommender/recommender.py in <module>()
#     140     intersection_movies,accuracy_rate,rmse  = pred.testaccuracy(all_movies_rec,intersection_movies,accuracy_rate,SVD_matrix,estimated_Ratings)
#     141
# --> 142 print( "The root squared error of ratings is", rmse)
#     143
#     144 print(Movie_Rec)
#
# NameError: name 'rmse' is not defined

# %%
#Reading ratings file:
# DataSource : http://grouplens.org/datasets/movielens/100k/
# Code Reference : http://antoinevastel.github.io/machine%20learning/python/2016/02/14/svd-recommender-system.html

r_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']
df_ratings = pd.read_csv('ml-100k/u.data', sep='\t', names=r_cols,
 encoding='latin-1')

# %%
#Reading items file:
i_cols = ['movie_id', 'movie_title' ,'release_date','video_release_date', 'IMDb_URL', 'unknown', 'Action', 'Adventure','Animation', 'Children\'s', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Fantasy','Film-Noir', 'Horror', 'Musical', 'Mystery', 'Romance', 'Sci-Fi', 'Thriller', 'War', 'Western']
items = pd.read_csv('ml-100k/u.item', sep='|', names = i_cols,encoding='latin-1')

# %%
'''Drop Timestamp & create a matrix '''
ratings = df_ratings.drop('unix_timestamp',1)

# %%
ratings.head(10)
# Out:
#    user_id  movie_id  rating
# 0      196       242       3
# 1      186       302       3
# 2       22       377       1
# 3      244        51       2
# 4      166       346       1
# 5      298       474       4
# 6      115       265       2
# 7      253       465       5
# 8      305       451       3
# 9        6        86       3

# %%
m, n = max(df_ratings['user_id']), max(df_ratings['movie_id'])
m,n
# Out:
# (943, 1682)

# %%
class MovieRecommender():

    def __init__(self, ratings):
        self.ratings = ratings
        self.movies_list = movies_list
        self.SVD_matrix = np.zeros(shape = (944, 1683), dtype = np.float32)
        self.user_Rec = dict()
        self.movies_Seen = dict()
        self.movies_pred = dict()
        self.all_movies_rec = dict()
        self.intersection_movies = dict()
        self.accuracy_rate = dict()
        self.rmse = 0 
        self.Movie_Rec = pd.Series(self.user_Rec, name = 'MovieID')

    def modifyRatingsDataset(self): 
        ''' Assign rating values to a matrix (userid, movieid ) '''
        for index, row in self.ratings.iterrows():
            self.SVD_matrix[ int(row[0]) , int(row[1])] = float(row[2])
        return csc_matrix(self.SVD_matrix, dtype=np.float32),self.SVD_matrix



    def UsersRating(self):  
        '''Create an empty dictionary that has key = userid and values = empty list '''
        for index, row in self.ratings.iterrows():
            self.user_Rec[int(row[0])] = list()
            self.movies_pred[int(row[0])] = list()
            self.all_movies_rec[int(row[0])] = list()
            self.intersection_movies[int(row[0])] = list()
            self.accuracy_rate[int(row[0])] = list()
            
        return self.user_Rec , self.movies_pred, self.all_movies_rec,self.intersection_movies,self.accuracy_rate


    def getMoviesSeen(self): 
        ''' Create a dictionary that has key = userid , values = list of movies that they have already rated '''
   
        for index, row in self.ratings.iterrows():
            try:
                self.movies_Seen[int(row[0])].append(int(row[1]))
            except:
                self.movies_Seen[int(row[0])] = list()
                self.movies_Seen[int(row[0])].append(int(row[1]))
        return self.movies_Seen

    
    def computeSVD(self,ratings, K):
        Ut,s,Vt = sparsesvd(ratings, K)

        dim = (len(s), len(s))
        S = np.zeros(dim, dtype = np.float32)
        for i in range(0,len(s)):
            S[i,i] = (s[i])

        U = csr_matrix(Ut.T, dtype=np.float32)
        S = csr_matrix(S, dtype=np.float32)
        Vt = csr_matrix(Vt, dtype=np.float32)
        return U,S,Vt

    def computeEstimatedRatings(self, user_Rec, U, S, Vt): 
        '''Compute Estimated Ratings by taking products of U S Vt '''
        rightTerm = S * Vt 
        estimated_Ratings = np.zeros(shape = (944, 1683), dtype = np.float16)
        for row in self.user_Rec:
            prod = U[row, :] * rightTerm
            estimated_Ratings[row, :] = ssp.coo_matrix.todense(prod)
            recom = (-estimated_Ratings[row, :]).argsort()[:250] #returns indice of values that sorted in order 
            for r in recom:
                self.all_movies_rec[row].append(r)
                if r not in movies_Seen[row]:
                    self.user_Rec[row].append(r)
                    if len(self.user_Rec[row]) == 5:
                        break
        return user_Rec, all_movies_rec,estimated_Ratings
    
    
    def getMovieNames(self,user_Rec, movies_pred, movies_list):
        ''' Replace movieIds with Movie Titles '''
        for key,value in self.user_Rec.items():
            for movie in value:
                self.movies_pred[key].append(movies_list[movie])
        return movies_pred
   

    def testaccuracy(self, intersection_movies, all_movies_rec,accuracy_rate,SVD_matrix,estimated_Ratings): #check to see movies that in moviesSeen list but not in the recommendation
        '''Calculate the Root Mean Square Error '''
        d = []
        for row in self.all_movies_rec:
            self.intersection_movies[row] = set.intersection(*[set(self.movies_Seen[row]), set(self.all_movies_rec[row])])
            for movie in intersection_movies[row]:
                self.accuracy_rate[row].append((estimated_Ratings[row, movie] - SVD_matrix[row, movie]) ** 2)
                d.append((estimated_Ratings[row, movie] - SVD_matrix[row, movie]) ** 2)
            
        self.rmse = np.sqrt(sum(d)/ sum([len(b) for b in self.accuracy_rate.values()]))
       
        return intersection_movies,accuracy_rate, self.rmse

# %%
if __name__ == '__main__':
    K = 50 

    r_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']
    df_ratings = pd.read_csv('ml-100k/u.data', sep='\t', names=r_cols,encoding='latin-1')
    ratings = df_ratings.drop('unix_timestamp',1)
    
    #Reading items file:
    i_cols = ['movie_id', 'movie_title' ,'release_date','video_release_date', 'IMDb_URL', 'unknown', 'Action', 'Adventure','Animation', 'Children\'s', 'Comedy', 'Crime', 'Documentary', 'Drama', 'Fantasy','Film-Noir', 'Horror', 'Musical', 'Mystery', 'Romance', 'Sci-Fi', 'Thriller', 'War', 'Western']
    items = pd.read_csv('ml-100k/u.item', sep='|', names = i_cols,encoding='latin-1')
    movies_list = dict()
    for index, row in items.iterrows():
        movies_list[int(row[0])] = str(row[1])
        
    #instantiate the class
    pred = MovieRecommender(ratings)
    ratings,SVD_matrix = pred.modifyRatingsDataset()
    U,S,Vt = pred.computeSVD(ratings,K)
    user_Rec,movies_pred, all_movies_rec,intersection_movies,accuracy_rate = pred.UsersRating()
    movies_Seen = pred.getMoviesSeen()
    user_Rec, all_movies_rec,estimated_Ratings = pred.computeEstimatedRatings(user_Rec,U,S,Vt)
    Movie_Rec = pred.getMovieNames(user_Rec,movies_pred, movies_list)
    intersection_movies,accuracy_rate,rmse  = pred.testaccuracy(all_movies_rec,intersection_movies,accuracy_rate,SVD_matrix,estimated_Ratings)

# %%
print( "The root squared error of ratings is", rmse)
# Out:
# The root squared error of ratings is 1.3988733003

# %%
Movie_Rec
# Out:
# {1: ['E.T. the Extra-Terrestrial (1982)',
#   'Batman (1989)',
#   'Dave (1993)',
#   "One Flew Over the Cuckoo's Nest (1975)",
#   'True Lies (1994)'],
#  2: ['Return of the Jedi (1983)',
#   'Lone Star (1996)',
#   "Mr. Holland's Opus (1995)",
#   'Amistad (1997)',
#   'Big Night (1996)'],
#  3: ['Gattaca (1997)',
#   'Peacemaker, The (1997)',
#   'In & Out (1997)',
#   'Saint, The (1997)',
#   'Titanic (1997)'],
#  4: ['Return of the Jedi (1983)',
#   'Saint, The (1997)',
#   'L.A. Confidential (1997)',
#   'Chasing Amy (1997)',
#   'Game, The (1997)'],
#  5: ['Brazil (1985)',
#   'Apollo 13 (1995)',
#   'Ed Wood (1994)',
#   'Terminator, The (1984)',
#   'Wallace & Gromit: The Best of Aardman Animation (1996)'],
#  6: ['Rear Window (1954)',
#   'Chinatown (1974)',
#   'Being There (1979)',
#   "Singin' in the Rain (1952)",
#   'It Happened One Night (1934)'],
#  7: ["Singin' in the Rain (1952)",
#   'Thin Man, The (1934)',
#   'Cape Fear (1991)',
#   'Little Women (1994)'],
#  8: ['Top Gun (1986)',
#   'Die Hard 2 (1990)',
#   'Hunt for Red October, The (1990)',
#   'Star Trek IV: The Voyage Home (1986)',
#   'Stargate (1994)'],
#  9: ['Godfather, The (1972)',
#   'Scream (1996)',
#   'Rock, The (1996)',
#   'Heat (1995)',
#   'Return of the Jedi (1983)'],
#  10: ['Streetcar Named Desire, A (1951)',
#   'Annie Hall (1977)',
#   'Scream (1996)',
#   'East of Eden (1955)',
#   'This Is Spinal Tap (1984)'],
#  11: ['Star Trek: Generations (1994)',
#   'Right Stuff, The (1983)',
#   'Sense and Sensibility (1995)',
#   'Courage Under Fire (1996)',
#   'Patton (1970)'],
#  12: ['E.T. the Extra-Terrestrial (1982)',
#   'Jerry Maguire (1996)',
#   'Indiana Jones and the Last Crusade (1989)',
#   'Shawshank Redemption, The (1994)',
#   'Aladdin (1992)'],
#  13: [],
#  14: ['Big Night (1996)',
#   'Contact (1997)',
#   'Glory (1989)',
#   'Toy Story (1995)',
#   'This Is Spinal Tap (1984)'],
#  15: ['Fly Away Home (1996)',
#   'Tin Cup (1996)',
#   'Fargo (1996)',
#   'Eraser (1996)',
#   'Kolya (1996)'],
#  16: ['Fish Called Wanda, A (1988)',
#   'Cape Fear (1991)',
#   'Jurassic Park (1993)',
#   'Dumbo (1941)',
#   'Aliens (1986)'],
#  17: ['Lone Star (1996)',
#   "Mr. Holland's Opus (1995)",
#   'Postino, Il (1994)',
#   'Air Force One (1997)',
#   'Secrets & Lies (1996)'],
#  18: ['Lone Star (1996)',
#   'Lawrence of Arabia (1962)',
#   'Deer Hunter, The (1978)',
#   'Princess Bride, The (1987)',
#   'Heathers (1989)'],
#  19: ['Princess Bride, The (1987)',
#   'Four Weddings and a Funeral (1994)',
#   'Air Force One (1997)',
#   'Back to the Future (1985)',
#   'When Harry Met Sally... (1989)'],
#  20: ['Fugitive, The (1993)',
#   'Wizard of Oz, The (1939)',
#   'Rock, The (1996)',
#   'Lion King, The (1994)',
#   "Schindler's List (1993)"],
#  21: ['Game, The (1997)',
#   'Return of the Jedi (1983)',
#   'Leaving Las Vegas (1995)',
#   'Alien (1979)',
#   'Rock, The (1996)'],
#  22: ['Jurassic Park (1993)',
#   'Heat (1995)',
#   'Alien (1979)',
#   'Good, The Bad and The Ugly, The (1966)',
#   'Braveheart (1995)'],
#  23: ['Monty Python and the Holy Grail (1974)',
#   'Big Night (1996)',
#   "It's a Wonderful Life (1946)",
#   'Maltese Falcon, The (1941)',
#   'Shining, The (1980)'],
#  24: ['Braveheart (1995)',
#   "Mr. Holland's Opus (1995)",
#   'Shine (1996)',
#   'Gandhi (1982)',
#   'Reservoir Dogs (1992)'],
#  25: ['Rear Window (1954)',
#   'Empire Strikes Back, The (1980)',
#   'Psycho (1960)',
#   'Indiana Jones and the Last Crusade (1989)',
#   'Monty Python and the Holy Grail (1974)'],
#  26: ['Lone Star (1996)',
#   'Heat (1995)',
#   'Good Will Hunting (1997)',
#   'Secrets & Lies (1996)',
#   "Devil's Own, The (1997)"],
#  27: ['Leaving Las Vegas (1995)',
#   'Rock, The (1996)',
#   'Twelve Monkeys (1995)',
#   'Return of the Jedi (1983)',
#   'Chasing Amy (1997)'],
#  28: ['Alien (1979)',
#   'Die Hard (1988)',
#   '2001: A Space Odyssey (1968)',
#   'Interview with the Vampire (1994)',
#   'Empire Strikes Back, The (1980)'],
#  29: ['Cop Land (1997)',
#   'Murder at 1600 (1997)',
#   'Conspiracy Theory (1997)',
#   'Fargo (1996)',
#   'Evita (1996)'],
#  30: ['Air Force One (1997)',
#   'L.A. Confidential (1997)',
#   'Braveheart (1995)',
#   'E.T. the Extra-Terrestrial (1982)',
#   'Amadeus (1984)'],
#  31: ['Vertigo (1958)',
#   'Full Monty, The (1997)',
#   'Rear Window (1954)',
#   'Cop Land (1997)',
#   'North by Northwest (1959)'],
#  32: ['Donnie Brasco (1997)',
#   'Toy Story (1995)',
#   'Independence Day (ID4) (1996)',
#   'Heat (1995)',
#   'Time to Kill, A (1996)'],
#  33: ['G.I. Jane (1997)',
#   'Saint, The (1997)',
#   'Murder at 1600 (1997)',
#   'Kiss the Girls (1997)',
#   'Edge, The (1997)'],
#  34: ['L.A. Confidential (1997)',
#   'Fly Away Home (1996)',
#   'Air Force One (1997)',
#   'Full Monty, The (1997)',
#   'In & Out (1997)'],
#  35: ['Liar Liar (1997)',
#   "Dante's Peak (1997)",
#   "Devil's Own, The (1997)",
#   'Edge, The (1997)',
#   "Devil's Advocate, The (1997)"],
#  36: ['Liar Liar (1997)',
#   'Air Force One (1997)',
#   'Cop Land (1997)',
#   'Kiss the Girls (1997)',
#   'Boogie Nights (1997)'],
#  37: ['Die Hard (1988)',
#   'Return of the Jedi (1983)',
#   'Godfather: Part II, The (1974)',
#   'In the Line of Fire (1993)',
#   'GoldenEye (1995)'],
#  38: ['Sound of Music, The (1965)',
#   'Air Force One (1997)',
#   'Babe (1995)',
#   'Back to the Future (1985)',
#   'Independence Day (ID4) (1996)'],
#  39: ['Boogie Nights (1997)',
#   'English Patient, The (1996)',
#   'Conspiracy Theory (1997)',
#   "Devil's Own, The (1997)",
#   'Chasing Amy (1997)'],
#  40: ['Cop Land (1997)',
#   'In & Out (1997)',
#   'Seven Years in Tibet (1997)',
#   "Devil's Advocate, The (1997)",
#   'Apt Pupil (1998)'],
#  41: ['Empire Strikes Back, The (1980)',
#   'Shawshank Redemption, The (1994)',
#   'Graduate, The (1967)',
#   'Gandhi (1982)',
#   'Back to the Future (1985)'],
#  42: ['Mrs. Doubtfire (1993)',
#   'Rock, The (1996)',
#   'Blues Brothers, The (1980)',
#   'Crimson Tide (1995)',
#   'North by Northwest (1959)'],
#  43: ["My Best Friend's Wedding (1997)",
#   'Pretty Woman (1990)',
#   'Crimson Tide (1995)',
#   'Grease (1978)',
#   'Sling Blade (1996)'],
#  44: ['Phenomenon (1996)',
#   'Apollo 13 (1995)',
#   "Monty Python's Life of Brian (1979)",
#   'Usual Suspects, The (1995)',
#   'Starship Troopers (1997)'],
#  45: ['Mission: Impossible (1996)',
#   'Star Trek: First Contact (1996)',
#   'Rock, The (1996)',
#   'Phenomenon (1996)',
#   'Sabrina (1995)'],
#  46: ['Contact (1997)',
#   "Dante's Peak (1997)",
#   'Toy Story (1995)',
#   'L.A. Confidential (1997)',
#   'Evita (1996)'],
#  47: ['Everyone Says I Love You (1996)',
#   'Kolya (1996)',
#   "Devil's Own, The (1997)",
#   'Gattaca (1997)',
#   'Air Force One (1997)'],
#  48: ['Citizen Kane (1941)',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)',
#   'Blade Runner (1982)',
#   'Princess Bride, The (1987)',
#   'Shawshank Redemption, The (1994)'],
#  49: ['Ransom (1996)',
#   'Reservoir Dogs (1992)',
#   "William Shakespeare's Romeo and Juliet (1996)",
#   'Heavenly Creatures (1994)',
#   'English Patient, The (1996)'],
#  50: ['Bound (1996)',
#   'Twelve Monkeys (1995)',
#   'Boogie Nights (1997)',
#   'Welcome to the Dollhouse (1995)',
#   'Game, The (1997)'],
#  51: ['Raiders of the Lost Ark (1981)',
#   'To Kill a Mockingbird (1962)',
#   'North by Northwest (1959)',
#   'Casablanca (1942)',
#   'Fugitive, The (1993)'],
#  52: ['Emma (1996)',
#   'Toy Story (1995)',
#   'Lone Star (1996)',
#   'People vs. Larry Flynt, The (1996)',
#   'Twister (1996)'],
#  53: ['Star Trek: First Contact (1996)',
#   'Toy Story (1995)',
#   'Rock, The (1996)',
#   'Jerry Maguire (1996)',
#   'Mission: Impossible (1996)'],
#  54: ['Air Force One (1997)',
#   'Donnie Brasco (1997)',
#   'Sleepers (1996)',
#   'Chasing Amy (1997)',
#   'Star Trek: First Contact (1996)'],
#  55: ['Empire Strikes Back, The (1980)',
#   'Terminator 2: Judgment Day (1991)',
#   'Star Trek: First Contact (1996)',
#   'Fifth Element, The (1997)',
#   'Indiana Jones and the Last Crusade (1989)'],
#  56: ['Men in Black (1997)',
#   'Pretty Woman (1990)',
#   'Young Frankenstein (1974)',
#   'Clear and Present Danger (1994)',
#   'Glory (1989)'],
#  57: ['Twister (1996)',
#   'Air Force One (1997)',
#   'Ransom (1996)',
#   'Braveheart (1995)',
#   "My Best Friend's Wedding (1997)"],
#  58: ['Graduate, The (1967)',
#   'Braveheart (1995)',
#   'Secrets & Lies (1996)',
#   'Terminator 2: Judgment Day (1991)',
#   'Ed Wood (1994)'],
#  59: ['Man Who Would Be King, The (1975)',
#   "Nobody's Fool (1994)",
#   'Sneakers (1992)',
#   'Mask, The (1994)',
#   'Philadelphia Story, The (1940)'],
#  60: ['Bonnie and Clyde (1967)',
#   'Manchurian Candidate, The (1962)',
#   'Sunset Blvd. (1950)',
#   'Snow White and the Seven Dwarfs (1937)',
#   'Fantasia (1940)'],
#  61: ['G.I. Jane (1997)',
#   'Titanic (1997)',
#   'Murder at 1600 (1997)',
#   'Peacemaker, The (1997)',
#   'L.A. Confidential (1997)'],
#  62: ['Seven (Se7en) (1995)',
#   'Brazil (1985)',
#   'Big Night (1996)',
#   'Sling Blade (1996)',
#   'In the Name of the Father (1993)'],
#  63: ['Sense and Sensibility (1995)',
#   'Lone Star (1996)',
#   'Twelve Monkeys (1995)',
#   'Welcome to the Dollhouse (1995)',
#   'Everyone Says I Love You (1996)'],
#  64: ['Back to the Future (1985)',
#   'Remains of the Day, The (1993)',
#   'Nikita (La Femme Nikita) (1990)',
#   'Shining, The (1980)',
#   'Apocalypse Now (1979)'],
#  65: ['Return of the Jedi (1983)',
#   'Back to the Future (1985)',
#   "One Flew Over the Cuckoo's Nest (1975)",
#   'Dave (1993)',
#   'Quiz Show (1994)'],
#  66: ['Twister (1996)',
#   'Star Trek: First Contact (1996)',
#   'Leaving Las Vegas (1995)',
#   "My Best Friend's Wedding (1997)",
#   'Fargo (1996)'],
#  67: ['Fargo (1996)',
#   'Twister (1996)',
#   'Eraser (1996)',
#   'Ransom (1996)',
#   'Jerry Maguire (1996)'],
#  68: ['Fargo (1996)',
#   "Mr. Holland's Opus (1995)",
#   'Toy Story (1995)',
#   'Star Trek: First Contact (1996)',
#   'Heat (1995)'],
#  69: ['Leaving Las Vegas (1995)',
#   'Toy Story (1995)',
#   'Cop Land (1997)',
#   'Shawshank Redemption, The (1994)',
#   'Welcome to the Dollhouse (1995)'],
#  70: ['Terminator, The (1984)',
#   'Winnie the Pooh and the Blustery Day (1968)',
#   'Heathers (1989)',
#   'Jungle Book, The (1994)',
#   'Dead Poets Society (1989)'],
#  71: ['Godfather, The (1972)',
#   'Dead Man Walking (1995)',
#   'Usual Suspects, The (1995)',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)',
#   'Full Monty, The (1997)'],
#  72: ['Raging Bull (1980)',
#   'Cool Hand Luke (1967)',
#   'Alien (1979)',
#   'Annie Hall (1977)',
#   'Fried Green Tomatoes (1991)'],
#  73: ['Amadeus (1984)',
#   'Taxi Driver (1976)',
#   'GoodFellas (1990)',
#   'Raiders of the Lost Ark (1981)',
#   'L.A. Confidential (1997)'],
#  74: ['English Patient, The (1996)',
#   'Sleepers (1996)',
#   'Full Monty, The (1997)',
#   'Trainspotting (1996)',
#   'As Good As It Gets (1997)'],
#  75: ['Twelve Monkeys (1995)',
#   'Sabrina (1995)',
#   'Happy Gilmore (1996)',
#   "Jackie Chan's First Strike (1996)",
#   'Time to Kill, A (1996)'],
#  76: ['Trainspotting (1996)',
#   'Heat (1995)',
#   'Dead Man Walking (1995)',
#   'Clockwork Orange, A (1971)',
#   'Psycho (1960)'],
#  77: ['Twelve Monkeys (1995)',
#   '2001: A Space Odyssey (1968)',
#   'Apocalypse Now (1979)',
#   'Braveheart (1995)',
#   'Sting, The (1973)'],
#  78: ['Air Force One (1997)',
#   'Mother (1996)',
#   'Truth About Cats & Dogs, The (1996)',
#   'Sense and Sensibility (1995)',
#   'Contact (1997)'],
#  79: ['L.A. Confidential (1997)',
#   'Postino, Il (1994)',
#   'Kolya (1996)',
#   'Trainspotting (1996)',
#   'Dead Man Walking (1995)'],
#  80: ["Schindler's List (1993)",
#   'Silence of the Lambs, The (1991)',
#   'Graduate, The (1967)',
#   'Chasing Amy (1997)',
#   'Butch Cassidy and the Sundance Kid (1969)'],
#  81: ['Rock, The (1996)',
#   "Mr. Holland's Opus (1995)",
#   'People vs. Larry Flynt, The (1996)',
#   'Broken Arrow (1996)',
#   'Sleepers (1996)'],
#  82: ['Aladdin (1992)',
#   'Princess Bride, The (1987)',
#   'Silence of the Lambs, The (1991)',
#   'African Queen, The (1951)',
#   'Back to the Future (1985)'],
#  83: ['Men in Black (1997)',
#   'Groundhog Day (1993)',
#   "Schindler's List (1993)",
#   'Ransom (1996)',
#   'Time to Kill, A (1996)'],
#  84: ['Dead Man Walking (1995)',
#   'Courage Under Fire (1996)',
#   'Twister (1996)',
#   'Phenomenon (1996)',
#   'L.A. Confidential (1997)'],
#  85: ["Muriel's Wedding (1994)",
#   'Leaving Las Vegas (1995)',
#   'In the Line of Fire (1993)',
#   'Alien (1979)',
#   'Maltese Falcon, The (1941)'],
#  86: ['L.A. Confidential (1997)',
#   'Liar Liar (1997)',
#   'In & Out (1997)',
#   'Seven Years in Tibet (1997)',
#   'Mother (1996)'],
#  87: ['Monty Python and the Holy Grail (1974)',
#   'Being There (1979)',
#   'Die Hard 2 (1990)',
#   'Amadeus (1984)',
#   'Tin Men (1987)'],
#  88: ['Good Will Hunting (1997)',
#   'Full Monty, The (1997)',
#   'Rainmaker, The (1997)',
#   'Evita (1996)',
#   'As Good As It Gets (1997)'],
#  89: ['Sabrina (1995)',
#   'Boogie Nights (1997)',
#   'Four Weddings and a Funeral (1994)',
#   'Annie Hall (1977)',
#   'Everyone Says I Love You (1996)'],
#  90: ['Roman Holiday (1953)',
#   'Jean de Florette (1986)',
#   'Quiz Show (1994)',
#   'Bonnie and Clyde (1967)',
#   'Christmas Carol, A (1938)'],
#  91: ['Bridge on the River Kwai, The (1957)',
#   'Taxi Driver (1976)',
#   "It's a Wonderful Life (1946)",
#   'Psycho (1960)',
#   'Cool Hand Luke (1967)'],
#  92: ['Four Weddings and a Funeral (1994)',
#   'Dances with Wolves (1990)',
#   'Star Trek: Generations (1994)',
#   'Casino (1995)',
#   'Wallace & Gromit: The Best of Aardman Animation (1996)'],
#  93: ['Truth About Cats & Dogs, The (1996)',
#   'Jerry Maguire (1996)',
#   'Sabrina (1995)',
#   'Birdcage, The (1996)',
#   'Star Wars (1977)'],
#  94: ['Hoop Dreams (1994)',
#   'Shine (1996)',
#   'Lawrence of Arabia (1962)',
#   "What's Eating Gilbert Grape (1993)",
#   'Nikita (La Femme Nikita) (1990)'],
#  95: ['Dave (1993)',
#   'Butch Cassidy and the Sundance Kid (1969)',
#   'Star Trek IV: The Voyage Home (1986)',
#   'Ben-Hur (1959)',
#   'Dumbo (1941)'],
#  96: ['Empire Strikes Back, The (1980)',
#   'Usual Suspects, The (1995)',
#   'Citizen Kane (1941)',
#   "One Flew Over the Cuckoo's Nest (1975)",
#   'Brazil (1985)'],
#  97: ['Aliens (1986)',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)',
#   'Pulp Fiction (1994)',
#   'This Is Spinal Tap (1984)',
#   'Return of the Jedi (1983)'],
#  98: ['Young Frankenstein (1974)',
#   'Back to the Future (1985)',
#   'Duck Soup (1933)',
#   'Blues Brothers, The (1980)',
#   'Being There (1979)'],
#  99: ['Willy Wonka and the Chocolate Factory (1971)',
#   'Stand by Me (1986)',
#   'To Kill a Mockingbird (1962)',
#   'Clerks (1994)',
#   'Tin Cup (1996)'],
#  100: ["Devil's Advocate, The (1997)",
#   'In & Out (1997)',
#   'Edge, The (1997)',
#   'Saint, The (1997)',
#   'Kiss the Girls (1997)'],
#  101: ['Executive Decision (1996)',
#   'Birdcage, The (1996)',
#   "Mr. Holland's Opus (1995)",
#   'First Wives Club, The (1996)',
#   'Sabrina (1995)'],
#  102: ['Game, The (1997)',
#   "Dante's Peak (1997)",
#   'This Is Spinal Tap (1984)',
#   'Conan the Barbarian (1981)',
#   'Apt Pupil (1998)'],
#  103: ['Toy Story (1995)',
#   'Face/Off (1997)',
#   'Raiders of the Lost Ark (1981)',
#   'Jerry Maguire (1996)',
#   'Contact (1997)'],
#  104: ['Apt Pupil (1998)',
#   'Toy Story (1995)',
#   'Face/Off (1997)',
#   'Willy Wonka and the Chocolate Factory (1971)',
#   'Boot, Das (1981)'],
#  105: ['Apt Pupil (1998)',
#   "Ulee's Gold (1997)",
#   'Jackie Brown (1997)',
#   'Air Force One (1997)',
#   "Devil's Own, The (1997)"],
#  106: ['Graduate, The (1967)',
#   'Shine (1996)',
#   'Jerry Maguire (1996)',
#   'Dave (1993)',
#   'Emma (1996)'],
#  107: ["Ulee's Gold (1997)",
#   'Good Will Hunting (1997)',
#   'In & Out (1997)',
#   'Everyone Says I Love You (1996)',
#   'Mrs. Brown (Her Majesty, Mrs. Brown) (1997)'],
#  108: ["Mr. Holland's Opus (1995)",
#   'Leaving Las Vegas (1995)',
#   'Dead Man Walking (1995)',
#   'Secrets & Lies (1996)',
#   'Men in Black (1997)'],
#  109: ['Fish Called Wanda, A (1988)',
#   'Net, The (1995)',
#   'While You Were Sleeping (1995)',
#   'Courage Under Fire (1996)',
#   'Young Guns (1988)'],
#  110: ['Indiana Jones and the Last Crusade (1989)',
#   'Conspiracy Theory (1997)',
#   'While You Were Sleeping (1995)',
#   'Stand by Me (1986)',
#   'Stargate (1994)'],
#  111: ['As Good As It Gets (1997)',
#   'Chasing Amy (1997)',
#   'Air Force One (1997)',
#   'Wag the Dog (1997)',
#   'Seven Years in Tibet (1997)'],
#  112: ['G.I. Jane (1997)',
#   'Fly Away Home (1996)',
#   'Gattaca (1997)',
#   'Boogie Nights (1997)',
#   'Rosewood (1997)'],
#  113: ['Return of the Jedi (1983)',
#   'Leaving Las Vegas (1995)',
#   'Saint, The (1997)',
#   'L.A. Confidential (1997)',
#   'Full Monty, The (1997)'],
#  114: ['Raiders of the Lost Ark (1981)',
#   'Usual Suspects, The (1995)',
#   'Psycho (1960)',
#   'Godfather, The (1972)',
#   'Godfather: Part II, The (1974)'],
#  115: ['GoodFellas (1990)',
#   'Leaving Las Vegas (1995)',
#   'Terminator, The (1984)',
#   'Rear Window (1954)',
#   'Boot, Das (1981)'],
#  116: ['As Good As It Gets (1997)',
#   'Donnie Brasco (1997)',
#   'Cop Land (1997)',
#   'Babe (1995)',
#   'Citizen Kane (1941)'],
#  117: ['Liar Liar (1997)',
#   'Fargo (1996)',
#   'Chasing Amy (1997)',
#   'Alien (1979)',
#   'Air Force One (1997)'],
#  118: ['Alien (1979)',
#   'Usual Suspects, The (1995)',
#   'Nightmare on Elm Street, A (1984)',
#   'Raising Arizona (1987)',
#   'Seven (Se7en) (1995)'],
#  119: ['Graduate, The (1967)',
#   "Devil's Advocate, The (1997)",
#   'Glory (1989)',
#   'Strictly Ballroom (1992)',
#   'Volcano (1997)'],
#  120: ['Return of the Jedi (1983)',
#   'Fargo (1996)',
#   'Courage Under Fire (1996)',
#   'Air Force One (1997)',
#   'Star Trek: First Contact (1996)'],
#  121: ['Shawshank Redemption, The (1994)',
#   'Room with a View, A (1986)',
#   'Trainspotting (1996)',
#   'Like Water For Chocolate (Como agua para chocolate) (1992)',
#   "Mr. Holland's Opus (1995)"],
#  122: ['Dead Poets Society (1989)',
#   'Room with a View, A (1986)',
#   'Boot, Das (1981)',
#   'Philadelphia (1993)',
#   'Clockwork Orange, A (1971)'],
#  123: ["Schindler's List (1993)",
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)',
#   'Chinatown (1974)',
#   'Amadeus (1984)',
#   "One Flew Over the Cuckoo's Nest (1975)"],
#  124: ['Pulp Fiction (1994)',
#   'Blade Runner (1982)',
#   'Return of the Jedi (1983)',
#   'Back to the Future (1985)',
#   'Alien (1979)'],
#  125: ['Rear Window (1954)',
#   'North by Northwest (1959)',
#   'Fifth Element, The (1997)',
#   'Star Trek: The Wrath of Khan (1982)',
#   'Cool Hand Luke (1967)'],
#  126: ['Saint, The (1997)',
#   "Devil's Advocate, The (1997)",
#   'Full Monty, The (1997)',
#   'Wag the Dog (1997)',
#   'Amistad (1997)'],
#  127: ['Conspiracy Theory (1997)',
#   'Return of the Jedi (1983)',
#   'Titanic (1997)',
#   "Mr. Holland's Opus (1995)",
#   "Dante's Peak (1997)"],
#  128: ["Schindler's List (1993)",
#   'Aladdin (1992)',
#   'Philadelphia (1993)',
#   'Scream (1996)',
#   'Vertigo (1958)'],
#  129: ['Seven Years in Tibet (1997)',
#   'Boogie Nights (1997)',
#   'Apt Pupil (1998)',
#   'In & Out (1997)',
#   'Mrs. Brown (Her Majesty, Mrs. Brown) (1997)'],
#  130: ['Fantasia (1940)',
#   "Dante's Peak (1997)",
#   'Dead Man Walking (1995)',
#   'Postino, Il (1994)',
#   'Rob Roy (1995)'],
#  131: ['Boot, Das (1981)',
#   'Cold Comfort Farm (1995)',
#   'Apt Pupil (1998)',
#   'Mighty Aphrodite (1995)',
#   'Emma (1996)'],
#  132: ['Postino, Il (1994)',
#   'Dead Man Walking (1995)',
#   'Godfather: Part II, The (1974)',
#   'Leaving Las Vegas (1995)',
#   'Trainspotting (1996)'],
#  133: ['L.A. Confidential (1997)',
#   'Wag the Dog (1997)',
#   'Seven Years in Tibet (1997)',
#   'Rainmaker, The (1997)',
#   'Saint, The (1997)'],
#  134: ['Good Will Hunting (1997)',
#   'Game, The (1997)',
#   'Scream (1996)',
#   'Seven Years in Tibet (1997)',
#   'Murder at 1600 (1997)'],
#  135: ['Star Trek: First Contact (1996)',
#   'Cape Fear (1991)',
#   'In the Line of Fire (1993)',
#   'Shining, The (1980)',
#   'L.A. Confidential (1997)'],
#  136: ['Secrets & Lies (1996)',
#   'Star Wars (1977)',
#   'Usual Suspects, The (1995)',
#   'People vs. Larry Flynt, The (1996)',
#   'L.A. Confidential (1997)'],
#  137: ['Twelve Monkeys (1995)',
#   'Contact (1997)',
#   'Aliens (1986)',
#   'Face/Off (1997)',
#   'Liar Liar (1997)'],
#  138: ['Jerry Maguire (1996)',
#   'Sense and Sensibility (1995)',
#   'Monty Python and the Holy Grail (1974)',
#   'Godfather, The (1972)',
#   'Wizard of Oz, The (1939)'],
#  139: ['Full Monty, The (1997)',
#   'Leaving Las Vegas (1995)',
#   'Dead Man Walking (1995)',
#   'Secrets & Lies (1996)',
#   'Boogie Nights (1997)'],
#  140: ['Full Monty, The (1997)',
#   'Cop Land (1997)',
#   'Air Force One (1997)',
#   'Boogie Nights (1997)',
#   'Kolya (1996)'],
#  141: ['Truth About Cats & Dogs, The (1996)',
#   'Executive Decision (1996)',
#   'That Thing You Do! (1996)',
#   'Con Air (1997)',
#   'Ghost and the Darkness, The (1996)'],
#  142: ['Titanic (1997)',
#   'Toy Story (1995)',
#   'Wallace & Gromit: The Best of Aardman Animation (1996)',
#   'Conspiracy Theory (1997)',
#   'Star Wars (1977)'],
#  143: ['Air Force One (1997)',
#   'Saint, The (1997)',
#   "Devil's Own, The (1997)",
#   'Tomorrow Never Dies (1997)',
#   'Volcano (1997)'],
#  144: ['Raising Arizona (1987)',
#   'Dances with Wolves (1990)',
#   'Philadelphia (1993)',
#   'Casablanca (1942)',
#   'Platoon (1986)'],
#  145: ['Good Will Hunting (1997)',
#   'Grosse Pointe Blank (1997)',
#   'Manchurian Candidate, The (1962)',
#   'Gandhi (1982)',
#   "Devil's Advocate, The (1997)"],
#  146: ['As Good As It Gets (1997)',
#   'Game, The (1997)',
#   'Scream (1996)',
#   'Amistad (1997)',
#   "Ulee's Gold (1997)"],
#  147: ['Good Will Hunting (1997)',
#   'Kolya (1996)',
#   'Apt Pupil (1998)',
#   "Ulee's Gold (1997)",
#   'Rainmaker, The (1997)'],
#  148: ['Alien (1979)',
#   'Young Frankenstein (1974)',
#   'Aliens (1986)',
#   'Terminator, The (1984)',
#   'Aladdin (1992)'],
#  149: ['Scream (1996)',
#   'Apt Pupil (1998)',
#   'Wag the Dog (1997)',
#   'Mrs. Brown (Her Majesty, Mrs. Brown) (1997)',
#   'Seven Years in Tibet (1997)'],
#  150: ['Twelve Monkeys (1995)',
#   'Rock, The (1996)',
#   'People vs. Larry Flynt, The (1996)',
#   'Dead Man Walking (1995)',
#   "Mr. Holland's Opus (1995)"],
#  151: ['Don Juan DeMarco (1995)',
#   'Sex, Lies, and Videotape (1989)',
#   'Farewell My Concubine (1993)',
#   'Firm, The (1993)',
#   'Hoop Dreams (1994)'],
#  152: ['When Harry Met Sally... (1989)',
#   'One Fine Day (1996)',
#   'Twister (1996)',
#   "Schindler's List (1993)",
#   'Walk in the Clouds, A (1995)'],
#  153: ["Schindler's List (1993)",
#   'Silence of the Lambs, The (1991)',
#   'Air Force One (1997)',
#   'Usual Suspects, The (1995)',
#   'Glory (1989)'],
#  154: ['Godfather, The (1972)',
#   'Rear Window (1954)',
#   'Casablanca (1942)',
#   'Taxi Driver (1976)',
#   'Citizen Kane (1941)'],
#  155: ['Game, The (1997)',
#   'Contact (1997)',
#   'Evita (1996)',
#   'Volcano (1997)',
#   'L.A. Confidential (1997)'],
#  156: ['Godfather, The (1972)',
#   'Lawrence of Arabia (1962)',
#   'Bridge on the River Kwai, The (1957)',
#   'Amadeus (1984)',
#   'Great Escape, The (1963)'],
#  157: ['Men in Black (1997)',
#   'Return of the Jedi (1983)',
#   'Dead Man Walking (1995)',
#   'Twelve Monkeys (1995)',
#   'Game, The (1997)'],
#  158: ['Fish Called Wanda, A (1988)',
#   'Mission: Impossible (1996)',
#   'M*A*S*H (1970)',
#   'Rear Window (1954)',
#   "Antonia's Line (1995)"],
#  159: ['Air Force One (1997)',
#   'Time to Kill, A (1996)',
#   'Long Kiss Goodnight, The (1996)',
#   'Dragonheart (1996)',
#   'Lost World: Jurassic Park, The (1997)'],
#  160: ['Raising Arizona (1987)',
#   'Vertigo (1958)',
#   'Die Hard (1988)',
#   'Graduate, The (1967)',
#   "One Flew Over the Cuckoo's Nest (1975)"],
#  161: ['Titanic (1997)',
#   "One Flew Over the Cuckoo's Nest (1975)",
#   'Boot, Das (1981)',
#   'Dead Poets Society (1989)',
#   'When Harry Met Sally... (1989)'],
#  162: ['Mission: Impossible (1996)',
#   'Men in Black (1997)',
#   'Time to Kill, A (1996)',
#   'Courage Under Fire (1996)',
#   'Pulp Fiction (1994)'],
#  163: ['L.A. Confidential (1997)',
#   'Apt Pupil (1998)',
#   'Fargo (1996)',
#   'Forrest Gump (1994)',
#   'Titanic (1997)'],
#  164: ['Broken Arrow (1996)',
#   'Men in Black (1997)',
#   'Long Kiss Goodnight, The (1996)',
#   'Peacemaker, The (1997)',
#   'Primal Fear (1996)'],
#  165: ['Star Wars (1977)',
#   'Liar Liar (1997)',
#   'Amadeus (1984)',
#   'Air Force One (1997)',
#   'Game, The (1997)'],
#  166: ['Volcano (1997)',
#   'Game, The (1997)',
#   'G.I. Jane (1997)',
#   "Devil's Own, The (1997)",
#   "Devil's Advocate, The (1997)"],
#  167: ['Princess Bride, The (1987)',
#   'Henry V (1989)',
#   "It's a Wonderful Life (1946)",
#   "Singin' in the Rain (1952)",
#   'Fugitive, The (1993)'],
#  168: ['Jerry Maguire (1996)',
#   'Truth About Cats & Dogs, The (1996)',
#   'Courage Under Fire (1996)',
#   'Star Wars (1977)',
#   'Face/Off (1997)'],
#  169: ['Vertigo (1958)',
#   'Indiana Jones and the Last Crusade (1989)',
#   'Conspiracy Theory (1997)',
#   'Manchurian Candidate, The (1962)',
#   'Fugitive, The (1993)'],
#  170: ['Saint, The (1997)',
#   'Peacemaker, The (1997)',
#   'Kiss the Girls (1997)',
#   "Devil's Advocate, The (1997)",
#   'Jungle2Jungle (1997)'],
#  171: ['Wag the Dog (1997)',
#   'As Good As It Gets (1997)',
#   'Amistad (1997)',
#   'In & Out (1997)',
#   'Wings of the Dove, The (1997)'],
#  172: ['Citizen Kane (1941)',
#   'Vertigo (1958)',
#   'Maltese Falcon, The (1941)',
#   'Psycho (1960)',
#   'Big Sleep, The (1946)'],
#  173: ['Game, The (1997)',
#   'Fly Away Home (1996)',
#   'Saint, The (1997)',
#   'Scream (1996)',
#   "Devil's Advocate, The (1997)"],
#  174: ['Miracle on 34th Street (1994)',
#   'Secrets & Lies (1996)',
#   'Sabrina (1995)',
#   'One Fine Day (1996)',
#   'As Good As It Gets (1997)'],
#  175: ["Schindler's List (1993)",
#   'Return of the Jedi (1983)',
#   'Raiders of the Lost Ark (1981)',
#   'Leaving Las Vegas (1995)',
#   'Fugitive, The (1993)'],
#  176: ['Full Monty, The (1997)',
#   'L.A. Confidential (1997)',
#   'Leaving Las Vegas (1995)',
#   'Toy Story (1995)',
#   'Game, The (1997)'],
#  177: ['Apocalypse Now (1979)',
#   'Heat (1995)',
#   'Stand by Me (1986)',
#   'Get Shorty (1995)',
#   'Jaws (1975)'],
#  178: ['GoodFellas (1990)',
#   'American President, The (1995)',
#   'Get Shorty (1995)',
#   'Wizard of Oz, The (1939)',
#   'One Fine Day (1996)'],
#  179: ['Conspiracy Theory (1997)',
#   'Chasing Amy (1997)',
#   'Kiss the Girls (1997)',
#   'Apostle, The (1997)',
#   'Gattaca (1997)'],
#  180: ['Field of Dreams (1989)',
#   'Monty Python and the Holy Grail (1974)',
#   'Clerks (1994)',
#   'Sneakers (1992)',
#   'Remains of the Day, The (1993)'],
#  181: ['Rainmaker, The (1997)',
#   'Boogie Nights (1997)',
#   "My Best Friend's Wedding (1997)",
#   'Heavenly Creatures (1994)',
#   'Jackal, The (1997)'],
#  182: ['Godfather, The (1972)',
#   'Contact (1997)',
#   "My Best Friend's Wedding (1997)",
#   'To Kill a Mockingbird (1962)',
#   'Shawshank Redemption, The (1994)'],
#  183: ['Clear and Present Danger (1994)',
#   'Alien (1979)',
#   'Blade Runner (1982)',
#   'Top Gun (1986)',
#   'American President, The (1995)'],
#  184: ['Gone with the Wind (1939)',
#   'Babe (1995)',
#   'On Golden Pond (1981)',
#   'Right Stuff, The (1983)',
#   '2001: A Space Odyssey (1968)'],
#  185: ['Fargo (1996)',
#   'Toy Story (1995)',
#   'Postino, Il (1994)',
#   'Men in Black (1997)',
#   'Lone Star (1996)'],
#  186: ['Courage Under Fire (1996)',
#   "Devil's Own, The (1997)",
#   'Peacemaker, The (1997)',
#   'Conspiracy Theory (1997)',
#   'Outbreak (1995)'],
#  187: ["Schindler's List (1993)",
#   'Stand by Me (1986)',
#   'Henry V (1989)',
#   'Sting, The (1973)',
#   'Raising Arizona (1987)'],
#  188: ['Alien (1979)',
#   'Rock, The (1996)',
#   'Time to Kill, A (1996)',
#   'Empire Strikes Back, The (1980)',
#   'Four Weddings and a Funeral (1994)'],
#  189: ['Secrets & Lies (1996)',
#   'My Life as a Dog (Mitt liv som hund) (1985)',
#   'My Left Foot (1989)',
#   'Alien (1979)',
#   'Annie Hall (1977)'],
#  190: ['Apt Pupil (1998)',
#   'Birdcage, The (1996)',
#   'Toy Story (1995)',
#   'English Patient, The (1996)',
#   "Devil's Advocate, The (1997)"],
#  191: ['Wag the Dog (1997)',
#   'Jackie Brown (1997)',
#   'Rainmaker, The (1997)',
#   'Seven Years in Tibet (1997)',
#   'Contact (1997)'],
#  192: ['Return of the Jedi (1983)',
#   'Toy Story (1995)',
#   'Star Trek: First Contact (1996)',
#   'English Patient, The (1996)',
#   'Jerry Maguire (1996)'],
#  193: ['Good Will Hunting (1997)',
#   'Die Hard 2 (1990)',
#   'Annie Hall (1977)',
#   'Under Siege (1992)',
#   'Apt Pupil (1998)'],
#  194: ['Killing Fields, The (1984)',
#   'Maltese Falcon, The (1941)',
#   'Hoop Dreams (1994)',
#   'North by Northwest (1959)',
#   'In the Line of Fire (1993)'],
#  195: ['Star Wars (1977)',
#   'Scream (1996)',
#   'Game, The (1997)',
#   'Trainspotting (1996)',
#   'Men in Black (1997)'],
#  196: ['When Harry Met Sally... (1989)',
#   'Back to the Future (1985)',
#   'Grease (1978)',
#   'Dave (1993)',
#   'Sleepless in Seattle (1993)'],
#  197: ['Apt Pupil (1998)',
#   'Die Hard (1988)',
#   'Full Monty, The (1997)',
#   'Fly Away Home (1996)',
#   'Rainmaker, The (1997)'],
#  198: ['Braveheart (1995)',
#   'Usual Suspects, The (1995)',
#   'This Is Spinal Tap (1984)',
#   'Groundhog Day (1993)',
#   'Platoon (1986)'],
#  199: ['Lone Star (1996)',
#   'Scream (1996)',
#   'Big Night (1996)',
#   'Game, The (1997)',
#   'Sense and Sensibility (1995)'],
#  200: ['Batman (1989)',
#   'Clear and Present Danger (1994)',
#   'Gone with the Wind (1939)',
#   'Ben-Hur (1959)',
#   'Apocalypse Now (1979)'],
#  201: ['2001: A Space Odyssey (1968)',
#   'Heathers (1989)',
#   'Rumble in the Bronx (1995)',
#   'Six Degrees of Separation (1993)',
#   'Sound of Music, The (1965)'],
#  202: ['Star Wars (1977)',
#   'L.A. Confidential (1997)',
#   'Raiders of the Lost Ark (1981)',
#   'Aliens (1986)',
#   'Alien (1979)'],
#  203: ['Air Force One (1997)',
#   "Mr. Holland's Opus (1995)",
#   'Face/Off (1997)',
#   'Independence Day (ID4) (1996)',
#   'Conspiracy Theory (1997)'],
#  204: ['Evita (1996)',
#   'Cop Land (1997)',
#   'Ice Storm, The (1997)',
#   'Mrs. Brown (Her Majesty, Mrs. Brown) (1997)',
#   'Good Will Hunting (1997)'],
#  205: ["Dante's Peak (1997)",
#   'Good Will Hunting (1997)',
#   "Devil's Own, The (1997)",
#   'L.A. Confidential (1997)',
#   'Seven Years in Tibet (1997)'],
#  206: ['As Good As It Gets (1997)',
#   'Wag the Dog (1997)',
#   'Tomorrow Never Dies (1997)',
#   "Devil's Advocate, The (1997)",
#   'Starship Troopers (1997)'],
#  207: ['Dances with Wolves (1990)',
#   'Mission: Impossible (1996)',
#   'Monty Python and the Holy Grail (1974)',
#   'Aliens (1986)',
#   'Cool Hand Luke (1967)'],
#  208: ['Dave (1993)',
#   'American President, The (1995)',
#   'Monty Python and the Holy Grail (1974)',
#   'Indiana Jones and the Last Crusade (1989)',
#   'Grease (1978)'],
#  209: ['Fargo (1996)',
#   'Boot, Das (1981)',
#   'Sense and Sensibility (1995)',
#   'Lone Star (1996)',
#   'Evita (1996)'],
#  210: ['Alien (1979)',
#   'Sting, The (1973)',
#   'Jurassic Park (1993)',
#   'Sound of Music, The (1965)',
#   'Gone with the Wind (1939)'],
#  211: ['Boot, Das (1981)',
#   'Apollo 13 (1995)',
#   'Lawrence of Arabia (1962)',
#   "Schindler's List (1993)",
#   'Right Stuff, The (1983)'],
#  212: ['Shawshank Redemption, The (1994)',
#   'Dead Poets Society (1989)',
#   'Field of Dreams (1989)',
#   'Right Stuff, The (1983)',
#   'Forrest Gump (1994)'],
#  213: ['Time to Kill, A (1996)',
#   'Fish Called Wanda, A (1988)',
#   'This Is Spinal Tap (1984)',
#   'Sling Blade (1996)',
#   'Braveheart (1995)'],
#  214: ['Raging Bull (1980)',
#   'Cinema Paradiso (1988)',
#   'Terminator 2: Judgment Day (1991)',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)',
#   'Donnie Brasco (1997)'],
#  215: ['2001: A Space Odyssey (1968)',
#   'Forrest Gump (1994)',
#   'Terminator 2: Judgment Day (1991)',
#   'Princess Bride, The (1987)',
#   'Butch Cassidy and the Sundance Kid (1969)'],
#  216: ['To Kill a Mockingbird (1962)',
#   'Rock, The (1996)',
#   'Blues Brothers, The (1980)',
#   'Lone Star (1996)',
#   'Sling Blade (1996)'],
#  217: ['Top Gun (1986)',
#   'Blade Runner (1982)',
#   'Professional, The (1994)',
#   'Good, The Bad and The Ugly, The (1966)',
#   'Full Metal Jacket (1987)'],
#  218: ['Fugitive, The (1993)',
#   'Raising Arizona (1987)',
#   'Reservoir Dogs (1992)',
#   'Jaws (1975)',
#   'Blade Runner (1982)'],
#  219: ['L.A. Confidential (1997)',
#   'Wrong Trousers, The (1993)',
#   'Mrs. Brown (Her Majesty, Mrs. Brown) (1997)',
#   'Chasing Amy (1997)',
#   "Monty Python's Life of Brian (1979)"],
#  220: ['L.A. Confidential (1997)',
#   'Cop Land (1997)',
#   'Mother (1996)',
#   "Devil's Own, The (1997)",
#   'Conspiracy Theory (1997)'],
#  221: ['Braveheart (1995)',
#   'Crow, The (1994)',
#   'Kingpin (1996)',
#   'GoldenEye (1995)',
#   'Under Siege (1992)'],
#  222: ['Unforgiven (1992)',
#   'Clerks (1994)',
#   'Heat (1995)',
#   'In the Line of Fire (1993)',
#   'Professional, The (1994)'],
#  223: ["Mr. Holland's Opus (1995)",
#   'Beauty and the Beast (1991)',
#   'Courage Under Fire (1996)',
#   'Volcano (1997)',
#   'One Fine Day (1996)'],
#  224: ['Courage Under Fire (1996)',
#   'Philadelphia (1993)',
#   'Quiz Show (1994)',
#   'Benny & Joon (1993)',
#   'Last of the Mohicans, The (1992)'],
#  225: ["It's a Wonderful Life (1946)",
#   'Casablanca (1942)',
#   'Citizen Kane (1941)',
#   'Wizard of Oz, The (1939)',
#   'Raiders of the Lost Ark (1981)'],
#  226: ['2001: A Space Odyssey (1968)',
#   'Wallace & Gromit: The Best of Aardman Animation (1996)',
#   "One Flew Over the Cuckoo's Nest (1975)",
#   'Grand Day Out, A (1992)',
#   'Trainspotting (1996)'],
#  227: ['People vs. Larry Flynt, The (1996)',
#   'Willy Wonka and the Chocolate Factory (1971)',
#   'Grosse Pointe Blank (1997)',
#   'Chasing Amy (1997)',
#   'Sense and Sensibility (1995)'],
#  228: ['Apt Pupil (1998)',
#   'Fargo (1996)',
#   'Contact (1997)',
#   'People vs. Larry Flynt, The (1996)',
#   'Boogie Nights (1997)'],
#  229: ['Jackie Brown (1997)',
#   'In & Out (1997)',
#   'Seven Years in Tibet (1997)',
#   'Rainmaker, The (1997)',
#   'Cop Land (1997)'],
#  230: ['Gone with the Wind (1939)',
#   'Willy Wonka and the Chocolate Factory (1971)',
#   "Schindler's List (1993)",
#   'Princess Bride, The (1987)',
#   'Old Yeller (1957)'],
#  231: ['Men in Black (1997)',
#   'Jerry Maguire (1996)',
#   'Contact (1997)',
#   'Twister (1996)',
#   'Truth About Cats & Dogs, The (1996)'],
#  232: ['Raiders of the Lost Ark (1981)',
#   'Gandhi (1982)',
#   'Willy Wonka and the Chocolate Factory (1971)',
#   'Citizen Kane (1941)',
#   'Usual Suspects, The (1995)'],
#  233: ['Apollo 13 (1995)',
#   'Wizard of Oz, The (1939)',
#   'Braveheart (1995)',
#   'Clockwork Orange, A (1971)',
#   'Annie Hall (1977)'],
#  234: ['My Life as a Dog (Mitt liv som hund) (1985)',
#   'Christmas Carol, A (1938)',
#   'Sense and Sensibility (1995)',
#   'Annie Hall (1977)',
#   'My Left Foot (1989)'],
#  235: ['Shawshank Redemption, The (1994)',
#   'Bridge on the River Kwai, The (1957)',
#   "One Flew Over the Cuckoo's Nest (1975)",
#   'Princess Bride, The (1987)',
#   'Godfather, The (1972)'],
#  236: ["One Flew Over the Cuckoo's Nest (1975)",
#   'Shine (1996)',
#   'Field of Dreams (1989)',
#   'Air Force One (1997)',
#   'Gandhi (1982)'],
#  237: ['2001: A Space Odyssey (1968)',
#   'North by Northwest (1959)',
#   'Sting, The (1973)',
#   'Maltese Falcon, The (1941)',
#   'Pulp Fiction (1994)'],
#  238: ['Rock, The (1996)',
#   'Evita (1996)',
#   'Star Trek: First Contact (1996)',
#   'Saint, The (1997)',
#   'Star Wars (1977)'],
#  239: ['Aliens (1986)',
#   'Secrets & Lies (1996)',
#   'Princess Bride, The (1987)',
#   "One Flew Over the Cuckoo's Nest (1975)",
#   'Three Colors: Red (1994)'],
#  240: ['Apt Pupil (1998)',
#   'Contact (1997)',
#   'Liar Liar (1997)',
#   'Game, The (1997)',
#   'Rainmaker, The (1997)'],
#  241: ['Full Monty, The (1997)',
#   'Conspiracy Theory (1997)',
#   'Game, The (1997)',
#   'Boogie Nights (1997)',
#   'Good Will Hunting (1997)'],
#  242: ['Full Monty, The (1997)',
#   "Mr. Holland's Opus (1995)",
#   'Air Force One (1997)',
#   'Ransom (1996)',
#   'Remains of the Day, The (1993)'],
#  243: ['Henry V (1989)',
#   'Lone Star (1996)',
#   'Fargo (1996)',
#   'Angels and Insects (1995)',
#   'Philadelphia (1993)'],
#  244: ['To Kill a Mockingbird (1962)',
#   'Much Ado About Nothing (1993)',
#   'Swingers (1996)',
#   'Brazil (1985)',
#   'First Wives Club, The (1996)'],
#  245: ['Independence Day (ID4) (1996)',
#   'Men in Black (1997)',
#   'Twister (1996)',
#   'Toy Story (1995)',
#   'Empire Strikes Back, The (1980)'],
#  246: ['Nightmare Before Christmas, The (1993)',
#   'Monty Python and the Holy Grail (1974)',
#   'Braveheart (1995)',
#   "William Shakespeare's Romeo and Juliet (1996)",
#   'Shining, The (1980)'],
#  247: ['L.A. Confidential (1997)',
#   'Jerry Maguire (1996)',
#   'Rock, The (1996)',
#   "Mr. Holland's Opus (1995)",
#   'Mission: Impossible (1996)'],
#  248: ['Pulp Fiction (1994)',
#   'Terminator, The (1984)',
#   'Usual Suspects, The (1995)',
#   'Princess Bride, The (1987)',
#   "One Flew Over the Cuckoo's Nest (1975)"],
#  249: ['Aladdin (1992)',
#   'Fish Called Wanda, A (1988)',
#   "It's a Wonderful Life (1946)",
#   'Heathers (1989)',
#   "Miller's Crossing (1990)"],
#  250: ['Snow White and the Seven Dwarfs (1937)',
#   'Seven (Se7en) (1995)',
#   'Fantasia (1940)',
#   "Mr. Holland's Opus (1995)",
#   'Braveheart (1995)'],
#  251: ['Silence of the Lambs, The (1991)',
#   "My Best Friend's Wedding (1997)",
#   'Broken Arrow (1996)',
#   'Princess Bride, The (1987)',
#   "Schindler's List (1993)"],
#  252: ['Jerry Maguire (1996)',
#   'Secrets & Lies (1996)',
#   'People vs. Larry Flynt, The (1996)',
#   'Swingers (1996)',
#   'Big Night (1996)'],
#  253: ['Willy Wonka and the Chocolate Factory (1971)',
#   'Aliens (1986)',
#   'Lion King, The (1994)',
#   'Die Hard (1988)',
#   'Godfather: Part II, The (1974)'],
#  254: ['Aladdin (1992)',
#   'Pinocchio (1940)',
#   'Right Stuff, The (1983)',
#   'Alice in Wonderland (1951)',
#   'Nightmare Before Christmas, The (1993)'],
#  255: ['Abyss, The (1989)',
#   'Evil Dead II (1987)',
#   'G.I. Jane (1997)',
#   'Game, The (1997)',
#   'Army of Darkness (1993)'],
#  256: ['Truth About Cats & Dogs, The (1996)',
#   'Alien (1979)',
#   'Aliens (1986)',
#   'Juror, The (1996)',
#   "It's a Wonderful Life (1946)"],
#  257: ['Dead Man Walking (1995)',
#   'Godfather, The (1972)',
#   'Cinema Paradiso (1988)',
#   "Mr. Holland's Opus (1995)",
#   'Boot, Das (1981)'],
#  258: ["Devil's Own, The (1997)",
#   'Murder at 1600 (1997)',
#   'Volcano (1997)',
#   "Devil's Advocate, The (1997)",
#   'Amistad (1997)'],
#  259: ['Star Wars (1977)',
#   'Alien (1979)',
#   'Pulp Fiction (1994)',
#   'Contact (1997)',
#   'To Kill a Mockingbird (1962)'],
#  260: ['Conspiracy Theory (1997)',
#   'Liar Liar (1997)',
#   'Starship Troopers (1997)',
#   "Dante's Peak (1997)",
#   "Devil's Own, The (1997)"],
#  261: ['Conspiracy Theory (1997)',
#   "Dante's Peak (1997)",
#   'Volcano (1997)',
#   'Game, The (1997)',
#   'Kiss the Girls (1997)'],
#  262: ['Dead Poets Society (1989)',
#   'Dead Man Walking (1995)',
#   'Field of Dreams (1989)',
#   "One Flew Over the Cuckoo's Nest (1975)",
#   'Princess Bride, The (1987)'],
#  263: ['M*A*S*H (1970)',
#   'Empire Strikes Back, The (1980)',
#   'Amadeus (1984)',
#   'Godfather: Part II, The (1974)',
#   'Right Stuff, The (1983)'],
#  264: ['Truth About Cats & Dogs, The (1996)',
#   'Aliens (1986)',
#   'Secrets & Lies (1996)',
#   'Cape Fear (1991)',
#   'Butch Cassidy and the Sundance Kid (1969)'],
#  265: ['Independence Day (ID4) (1996)',
#   'Mission: Impossible (1996)',
#   'Star Trek: First Contact (1996)',
#   'Birdcage, The (1996)',
#   'Leaving Las Vegas (1995)'],
#  266: ['Trainspotting (1996)',
#   'Full Monty, The (1997)',
#   'Cold Comfort Farm (1995)',
#   'Big Night (1996)',
#   "Antonia's Line (1995)"],
#  267: ['Terminator 2: Judgment Day (1991)',
#   'Fugitive, The (1993)',
#   'Get Shorty (1995)',
#   'Citizen Kane (1941)',
#   "Monty Python's Life of Brian (1979)"],
#  268: ['Highlander (1986)',
#   'Brazil (1985)',
#   'Saint, The (1997)',
#   'Groundhog Day (1993)',
#   'Mystery Science Theater 3000: The Movie (1996)'],
#  269: ['Birds, The (1963)',
#   'Usual Suspects, The (1995)',
#   'In the Name of the Father (1993)',
#   'Crumb (1994)',
#   'Smoke (1995)'],
#  270: ['Omen, The (1976)',
#   'Chasing Amy (1997)',
#   'American Werewolf in London, An (1981)',
#   "Mary Shelley's Frankenstein (1994)",
#   'American President, The (1995)'],
#  271: ['Taxi Driver (1976)',
#   'Postino, Il (1994)',
#   'In the Line of Fire (1993)',
#   'Lion King, The (1994)',
#   'While You Were Sleeping (1995)'],
#  272: ['GoodFellas (1990)',
#   'Psycho (1960)',
#   'Apocalypse Now (1979)',
#   'Butch Cassidy and the Sundance Kid (1969)',
#   'Aliens (1986)'],
#  273: ['L.A. Confidential (1997)',
#   'Full Monty, The (1997)',
#   'Amistad (1997)',
#   'Jackie Brown (1997)',
#   'Rainmaker, The (1997)'],
#  274: ['Independence Day (ID4) (1996)',
#   'Star Trek: First Contact (1996)',
#   'Twelve Monkeys (1995)',
#   'Willy Wonka and the Chocolate Factory (1971)',
#   'Tin Cup (1996)'],
#  275: ['Empire Strikes Back, The (1980)',
#   'Jurassic Park (1993)',
#   'Willy Wonka and the Chocolate Factory (1971)',
#   'Terminator, The (1984)',
#   'Monty Python and the Holy Grail (1974)'],
#  276: ['Welcome to the Dollhouse (1995)'],
#  277: ['Trainspotting (1996)',
#   'Phenomenon (1996)',
#   'Godfather, The (1972)',
#   'Star Trek: First Contact (1996)',
#   'Swingers (1996)'],
#  278: ['Good Will Hunting (1997)',
#   'Amistad (1997)',
#   'Air Force One (1997)',
#   'Boogie Nights (1997)',
#   'Fargo (1996)'],
#  279: ['Saint, The (1997)',
#   'Postino, Il (1994)',
#   "Muriel's Wedding (1994)",
#   'Sound of Music, The (1965)',
#   'Frighteners, The (1996)'],
#  280: ['Sound of Music, The (1965)',
#   'Blade Runner (1982)',
#   'Heat (1995)',
#   'Boot, Das (1981)',
#   'Shawshank Redemption, The (1994)'],
#  281: ['Conspiracy Theory (1997)',
#   'Volcano (1997)',
#   'Peacemaker, The (1997)',
#   "Devil's Own, The (1997)",
#   "Devil's Advocate, The (1997)"],
#  282: ['In & Out (1997)',
#   "Ulee's Gold (1997)",
#   'Conspiracy Theory (1997)',
#   'English Patient, The (1996)',
#   'Mother (1996)'],
#  283: ['Toy Story (1995)',
#   'Birdcage, The (1996)',
#   'Duck Soup (1933)',
#   "Monty Python's Life of Brian (1979)",
#   'Babe (1995)'],
#  284: ['As Good As It Gets (1997)',
#   'Cop Land (1997)',
#   'Wings of the Dove, The (1997)',
#   'Kolya (1996)',
#   'Edge, The (1997)'],
#  285: ['Liar Liar (1997)',
#   'Toy Story (1995)',
#   'Boogie Nights (1997)',
#   'Twelve Monkeys (1995)',
#   'Good Will Hunting (1997)'],
#  286: ['Raising Arizona (1987)',
#   'Silence of the Lambs, The (1991)',
#   "My Best Friend's Wedding (1997)",
#   'Celluloid Closet, The (1995)',
#   'That Thing You Do! (1996)'],
#  287: ['Usual Suspects, The (1995)',
#   'Scream (1996)',
#   'Twelve Monkeys (1995)',
#   'Air Force One (1997)',
#   'Willy Wonka and the Chocolate Factory (1971)'],
#  288: ['Godfather: Part II, The (1974)',
#   'Amadeus (1984)',
#   'Full Metal Jacket (1987)',
#   'Cool Hand Luke (1967)',
#   'Toy Story (1995)'],
#  289: ['Twister (1996)',
#   'Jerry Maguire (1996)',
#   'Eraser (1996)',
#   'Broken Arrow (1996)',
#   'Birdcage, The (1996)'],
#  290: ['Field of Dreams (1989)',
#   'Terminator, The (1984)',
#   'Blues Brothers, The (1980)',
#   'North by Northwest (1959)',
#   'Dumbo (1941)'],
#  291: ['Crow, The (1994)',
#   'Jaws 2 (1978)',
#   'Under Siege (1992)',
#   "One Flew Over the Cuckoo's Nest (1975)",
#   'Sleepers (1996)'],
#  292: ['Usual Suspects, The (1995)',
#   'North by Northwest (1959)',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)',
#   'Citizen Kane (1941)',
#   'Blade Runner (1982)'],
#  293: ['Amadeus (1984)',
#   'Graduate, The (1967)',
#   'American President, The (1995)',
#   'Quiz Show (1994)',
#   "Monty Python's Life of Brian (1979)"],
#  294: ['Happy Gilmore (1996)',
#   'Executive Decision (1996)',
#   'Gattaca (1997)',
#   'L.A. Confidential (1997)',
#   'Good Will Hunting (1997)'],
#  295: ['Rock, The (1996)',
#   'Mrs. Doubtfire (1993)',
#   'Fantasia (1940)',
#   'Return of the Pink Panther, The (1974)',
#   'Heathers (1989)'],
#  296: ['Raiders of the Lost Ark (1981)',
#   'Wizard of Oz, The (1939)',
#   'Alien (1979)',
#   'Terminator, The (1984)',
#   'Lawrence of Arabia (1962)'],
#  297: ['Apocalypse Now (1979)',
#   'Independence Day (ID4) (1996)',
#   'Abyss, The (1989)',
#   'Terminator 2: Judgment Day (1991)',
#   'Casablanca (1942)'],
#  298: ['Princess Bride, The (1987)',
#   'Shawshank Redemption, The (1994)',
#   'Aladdin (1992)',
#   'Amadeus (1984)',
#   'Chinatown (1974)'],
#  299: ["Singin' in the Rain (1952)",
#   'Duck Soup (1933)',
#   'Manchurian Candidate, The (1962)',
#   'Cold Comfort Farm (1995)',
#   'Strictly Ballroom (1992)'],
#  300: ['Volcano (1997)',
#   "Dante's Peak (1997)",
#   'Saint, The (1997)',
#   'G.I. Jane (1997)',
#   'George of the Jungle (1997)'],
#  301: ['Men in Black (1997)',
#   'Full Metal Jacket (1987)',
#   'Mask, The (1994)',
#   'Demolition Man (1993)',
#   'Searching for Bobby Fischer (1993)'],
#  302: ['Air Force One (1997)',
#   'G.I. Jane (1997)',
#   'Volcano (1997)',
#   'Kiss the Girls (1997)',
#   'Edge, The (1997)'],
#  303: ['Quiz Show (1994)',
#   'While You Were Sleeping (1995)',
#   'Kolya (1996)',
#   "It's a Wonderful Life (1946)",
#   "Bram Stoker's Dracula (1992)"],
#  304: ['Saint, The (1997)',
#   'Volcano (1997)',
#   'G.I. Jane (1997)',
#   "Devil's Advocate, The (1997)",
#   'Game, The (1997)'],
#  305: ['My Left Foot (1989)',
#   'Wallace & Gromit: The Best of Aardman Animation (1996)',
#   'Hunt for Red October, The (1990)',
#   'Boot, Das (1981)',
#   'Rosencrantz and Guildenstern Are Dead (1990)'],
#  306: ['Big Night (1996)',
#   'Lone Star (1996)',
#   'L.A. Confidential (1997)',
#   'In & Out (1997)',
#   'Sabrina (1995)'],
#  307: ['Fantasia (1940)',
#   'Raising Arizona (1987)',
#   'Aladdin (1992)',
#   'Clockwork Orange, A (1971)',
#   'Amadeus (1984)'],
#  308: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)',
#   'Bringing Up Baby (1938)',
#   'Notorious (1946)',
#   'Ran (1985)',
#   'Cinderella (1950)'],
#  309: ['Conspiracy Theory (1997)',
#   'L.A. Confidential (1997)',
#   'Saint, The (1997)',
#   'Liar Liar (1997)',
#   'Full Monty, The (1997)'],
#  310: ['Emma (1996)',
#   'Godfather, The (1972)',
#   "Mr. Holland's Opus (1995)",
#   "My Best Friend's Wedding (1997)",
#   'Fifth Element, The (1997)'],
#  311: ['Aladdin (1992)',
#   'Rear Window (1954)',
#   'Butch Cassidy and the Sundance Kid (1969)',
#   'To Kill a Mockingbird (1962)',
#   'Willy Wonka and the Chocolate Factory (1971)'],
#  312: ['Bringing Up Baby (1938)',
#   'East of Eden (1955)',
#   'Like Water For Chocolate (Como agua para chocolate) (1992)',
#   'Remains of the Day, The (1993)',
#   'Gandhi (1982)'],
#  313: ["Singin' in the Rain (1952)",
#   'Magnificent Seven, The (1954)',
#   'Man Who Would Be King, The (1975)',
#   'Full Metal Jacket (1987)',
#   'Killing Fields, The (1984)'],
#  314: ['Grease (1978)',
#   'Courage Under Fire (1996)',
#   'Cool Runnings (1993)',
#   'I.Q. (1994)',
#   'Homeward Bound: The Incredible Journey (1993)'],
#  315: ['GoodFellas (1990)',
#   'Indiana Jones and the Last Crusade (1989)',
#   'Chasing Amy (1997)',
#   'Stand by Me (1986)',
#   'Annie Hall (1977)'],
#  316: ['Remains of the Day, The (1993)',
#   'Gandhi (1982)',
#   'My Left Foot (1989)',
#   'Lawrence of Arabia (1962)',
#   'Sting, The (1973)'],
#  317: ['Game, The (1997)',
#   'Liar Liar (1997)',
#   "Devil's Advocate, The (1997)",
#   'Contact (1997)',
#   'Kiss the Girls (1997)'],
#  318: ['Groundhog Day (1993)',
#   'Fish Called Wanda, A (1988)',
#   'Dances with Wolves (1990)',
#   'Apocalypse Now (1979)',
#   'Good Will Hunting (1997)'],
#  319: ['Good Will Hunting (1997)',
#   'Scream (1996)',
#   'Wag the Dog (1997)',
#   'Apt Pupil (1998)',
#   'Starship Troopers (1997)'],
#  320: ['Professional, The (1994)',
#   'Die Hard (1988)',
#   "Jackie Chan's First Strike (1996)",
#   'Return of the Jedi (1983)',
#   'Demolition Man (1993)'],
#  321: ['Some Like It Hot (1959)',
#   'Killing Fields, The (1984)',
#   'To Kill a Mockingbird (1962)',
#   'Jean de Florette (1986)',
#   'This Is Spinal Tap (1984)'],
#  322: ['Godfather: Part II, The (1974)',
#   '2001: A Space Odyssey (1968)',
#   "One Flew Over the Cuckoo's Nest (1975)",
#   'Citizen Kane (1941)',
#   'North by Northwest (1959)'],
#  323: ['Raiders of the Lost Ark (1981)',
#   'Usual Suspects, The (1995)',
#   'Leaving Las Vegas (1995)',
#   'Con Air (1997)',
#   'Fifth Element, The (1997)'],
#  324: ['Game, The (1997)',
#   'G.I. Jane (1997)',
#   "Devil's Own, The (1997)",
#   'Return of the Jedi (1983)',
#   'Rock, The (1996)'],
#  325: ['Sting, The (1973)',
#   'E.T. the Extra-Terrestrial (1982)',
#   'Rear Window (1954)',
#   'Wrong Trousers, The (1993)',
#   'Manchurian Candidate, The (1962)'],
#  326: ["One Flew Over the Cuckoo's Nest (1975)",
#   'Field of Dreams (1989)',
#   'Highlander (1986)',
#   'Full Metal Jacket (1987)',
#   'Duck Soup (1933)'],
#  327: ['Quiz Show (1994)',
#   "It's a Wonderful Life (1946)",
#   'Sting, The (1973)',
#   'Young Frankenstein (1974)',
#   'To Kill a Mockingbird (1962)'],
#  328: ['Right Stuff, The (1983)',
#   'Sleepless in Seattle (1993)',
#   'Leaving Las Vegas (1995)',
#   'Gandhi (1982)',
#   'Chinatown (1974)'],
#  329: ['Apt Pupil (1998)',
#   'Dead Man Walking (1995)',
#   'Saint, The (1997)',
#   'Conspiracy Theory (1997)',
#   'North by Northwest (1959)'],
#  330: ['Ghost (1990)',
#   'African Queen, The (1951)',
#   'Clueless (1995)',
#   'Pinocchio (1940)',
#   'Ransom (1996)'],
#  331: ["Ulee's Gold (1997)",
#   'Usual Suspects, The (1995)',
#   "Schindler's List (1993)",
#   'Searching for Bobby Fischer (1993)',
#   'Bridge on the River Kwai, The (1957)'],
# ...
#   'Cold Comfort Farm (1995)',
#   'Star Wars (1977)',
#   'Spitfire Grill, The (1996)'],
#  838: ['Aladdin (1992)',
#   'Beauty and the Beast (1991)',
#   'Terminator, The (1984)',
#   'Die Hard (1988)',
#   "It's a Wonderful Life (1946)"],
#  839: ['Dead Man Walking (1995)',
#   'Heat (1995)',
#   'Birdcage, The (1996)',
#   "Mr. Holland's Opus (1995)",
#   'Star Trek: First Contact (1996)'],
#  840: ['Gandhi (1982)',
#   'M*A*S*H (1970)',
#   'Remains of the Day, The (1993)',
#   'Cool Hand Luke (1967)',
#   'Man Who Would Be King, The (1975)'],
#  841: ['Conspiracy Theory (1997)',
#   "Devil's Own, The (1997)",
#   'Liar Liar (1997)',
#   'Amistad (1997)',
#   'Seven Years in Tibet (1997)'],
#  842: ['Wag the Dog (1997)',
#   'Cop Land (1997)',
#   'Starship Troopers (1997)',
#   'As Good As It Gets (1997)',
#   'Jackie Brown (1997)'],
#  843: ['Interview with the Vampire (1994)',
#   'Men in Black (1997)',
#   'Heathers (1989)',
#   'Great Escape, The (1963)',
#   'Magnificent Seven, The (1954)'],
#  844: ['Terminator 2: Judgment Day (1991)',
#   'Toy Story (1995)',
#   'Fugitive, The (1993)',
#   'Alien (1979)',
#   'Back to the Future (1985)'],
#  845: ['Apt Pupil (1998)',
#   'Wag the Dog (1997)',
#   'As Good As It Gets (1997)',
#   'Ice Storm, The (1997)',
#   'Apostle, The (1997)'],
#  846: ['Ghost (1990)',
#   'Three Musketeers, The (1993)',
#   'Stargate (1994)',
#   'Cinema Paradiso (1988)',
#   'Apartment, The (1960)'],
#  847: ['Sound of Music, The (1965)',
#   'American President, The (1995)',
#   'Fantasia (1940)',
#   'Star Trek IV: The Voyage Home (1986)',
#   'Brazil (1985)'],
#  848: ['Brazil (1985)',
#   'M*A*S*H (1970)',
#   'Monty Python and the Holy Grail (1974)',
#   "Singin' in the Rain (1952)",
#   'Sound of Music, The (1965)'],
#  849: ['Titanic (1997)',
#   'Return of the Jedi (1983)',
#   'Indiana Jones and the Last Crusade (1989)',
#   'Star Wars (1977)',
#   'Willy Wonka and the Chocolate Factory (1971)'],
#  850: ['When Harry Met Sally... (1989)',
#   'Toy Story (1995)',
#   'E.T. the Extra-Terrestrial (1982)',
#   'Blues Brothers, The (1980)',
#   'To Kill a Mockingbird (1962)'],
#  851: ['Broken Arrow (1996)',
#   'Twister (1996)',
#   'As Good As It Gets (1997)',
#   'Gattaca (1997)',
#   'Murder at 1600 (1997)'],
#  852: ['Star Trek: First Contact (1996)',
#   'Rumble in the Bronx (1995)',
#   'Face/Off (1997)',
#   "Jackie Chan's First Strike (1996)",
#   'Saint, The (1997)'],
#  853: ['Evita (1996)',
#   'Mother (1996)',
#   'Jungle2Jungle (1997)',
#   'Everyone Says I Love You (1996)',
#   'Event Horizon (1997)'],
#  854: ['Alien (1979)',
#   'Big Night (1996)',
#   'Grosse Pointe Blank (1997)',
#   'Philadelphia Story, The (1940)',
#   'Gandhi (1982)'],
#  855: ['Postino, Il (1994)',
#   'Three Colors: White (1994)',
#   'Cyrano de Bergerac (1990)',
#   'Room with a View, A (1986)',
#   'Unbearable Lightness of Being, The (1988)'],
#  856: ['Tomorrow Never Dies (1997)',
#   'Game, The (1997)',
#   'L.A. Confidential (1997)',
#   "Devil's Own, The (1997)",
#   'Edge, The (1997)'],
#  857: ['English Patient, The (1996)',
#   'Big Night (1996)',
#   'Secrets & Lies (1996)',
#   "Mr. Holland's Opus (1995)",
#   'Lone Star (1996)'],
#  858: ['Leaving Las Vegas (1995)',
#   'Air Force One (1997)',
#   'Star Wars (1977)',
#   'L.A. Confidential (1997)',
#   'Murder at 1600 (1997)'],
#  859: ['People vs. Larry Flynt, The (1996)',
#   "My Best Friend's Wedding (1997)",
#   'Sabrina (1995)',
#   'Swingers (1996)',
#   'Jerry Maguire (1996)'],
#  860: ['Amistad (1997)',
#   'Sleepless in Seattle (1993)',
#   'Boogie Nights (1997)',
#   'Birdcage, The (1996)',
#   'While You Were Sleeping (1995)'],
#  861: ['Emma (1996)',
#   'Full Monty, The (1997)',
#   'Enchanted April (1991)',
#   'Henry V (1989)',
#   'Secrets & Lies (1996)'],
#  862: ['Lawrence of Arabia (1962)',
#   "William Shakespeare's Romeo and Juliet (1996)",
#   'Twister (1996)',
#   'Phenomenon (1996)',
#   'Jaws (1975)'],
#  863: ["Devil's Own, The (1997)",
#   "Dante's Peak (1997)",
#   'Midnight in the Garden of Good and Evil (1997)',
#   'Wings of the Dove, The (1997)',
#   'Event Horizon (1997)'],
#  864: ['True Lies (1994)',
#   'Piano, The (1993)',
#   'Much Ado About Nothing (1993)',
#   'L.A. Confidential (1997)',
#   'Crow, The (1994)'],
#  865: ['Willy Wonka and the Chocolate Factory (1971)',
#   'English Patient, The (1996)',
#   'Wallace & Gromit: The Best of Aardman Animation (1996)',
#   'Long Kiss Goodnight, The (1996)',
#   'Mars Attacks! (1996)'],
#  866: ['Chasing Amy (1997)',
#   'English Patient, The (1996)',
#   'Amistad (1997)',
#   'Contact (1997)',
#   'As Good As It Gets (1997)'],
#  867: ['Fargo (1996)',
#   "One Flew Over the Cuckoo's Nest (1975)",
#   'Gandhi (1982)',
#   'Princess Bride, The (1987)',
#   'This Is Spinal Tap (1984)'],
#  868: ['Brazil (1985)',
#   'Die Hard (1988)',
#   'GoodFellas (1990)',
#   'Dead Poets Society (1989)',
#   "One Flew Over the Cuckoo's Nest (1975)"],
#  869: ['Toy Story (1995)',
#   'Men in Black (1997)',
#   'Postino, Il (1994)',
#   'Secrets & Lies (1996)',
#   'Dead Man Walking (1995)'],
#  870: ['Brazil (1985)',
#   'Godfather: Part II, The (1974)',
#   'Sex, Lies, and Videotape (1989)',
#   'Fried Green Tomatoes (1991)',
#   'Reservoir Dogs (1992)'],
#  871: ['As Good As It Gets (1997)',
#   'Aliens (1986)',
#   'Speed (1994)',
#   'Boogie Nights (1997)',
#   'Scream (1996)'],
#  872: ["Mr. Holland's Opus (1995)",
#   'Courage Under Fire (1996)',
#   'Birdcage, The (1996)',
#   'Phenomenon (1996)',
#   'Michael (1996)'],
#  873: ['Scream (1996)',
#   'Saint, The (1997)',
#   'Game, The (1997)',
#   "Dante's Peak (1997)",
#   'Volcano (1997)'],
#  874: ['Full Monty, The (1997)',
#   'Godfather: Part II, The (1974)',
#   'Dead Man Walking (1995)',
#   'Taxi Driver (1976)',
#   'Emma (1996)'],
#  875: ['Fugitive, The (1993)',
#   'Casablanca (1942)',
#   'Manchurian Candidate, The (1962)',
#   'Blade Runner (1982)',
#   'Indiana Jones and the Last Crusade (1989)'],
#  876: ['Glory (1989)',
#   'Godfather, The (1972)',
#   'Amadeus (1984)',
#   'Shawshank Redemption, The (1994)',
#   'Babe (1995)'],
#  877: ['Room with a View, A (1986)',
#   'Dances with Wolves (1990)',
#   'Nikita (La Femme Nikita) (1990)',
#   'While You Were Sleeping (1995)',
#   'In the Line of Fire (1993)'],
#  878: ['Remains of the Day, The (1993)',
#   "One Flew Over the Cuckoo's Nest (1975)",
#   'Forrest Gump (1994)',
#   'Indiana Jones and the Last Crusade (1989)',
#   'Trainspotting (1996)'],
#  879: ['Men in Black (1997)',
#   'Mission: Impossible (1996)',
#   'Courage Under Fire (1996)',
#   'Fargo (1996)',
#   'That Thing You Do! (1996)'],
#  880: ['Maverick (1994)',
#   'While You Were Sleeping (1995)',
#   'Gattaca (1997)',
#   'Hunt for Red October, The (1990)',
#   'Boogie Nights (1997)'],
#  881: ['M*A*S*H (1970)',
#   'Indiana Jones and the Last Crusade (1989)',
#   "Schindler's List (1993)",
#   'Vertigo (1958)',
#   "It's a Wonderful Life (1946)"],
#  882: ['Dances with Wolves (1990)',
#   'Braveheart (1995)',
#   'Sleepless in Seattle (1993)',
#   'Cinderella (1950)',
#   "Schindler's List (1993)"],
#  883: ['Return of the Jedi (1983)',
#   'Mars Attacks! (1996)',
#   'Searching for Bobby Fischer (1993)',
#   'Amadeus (1984)',
#   'Tomorrow Never Dies (1997)'],
#  884: ['Leaving Las Vegas (1995)',
#   'Three Colors: Blue (1993)',
#   'Three Colors: Red (1994)',
#   'Eat Drink Man Woman (1994)',
#   'Cinema Paradiso (1988)'],
#  885: ['Independence Day (ID4) (1996)',
#   'Close Shave, A (1995)',
#   'Groundhog Day (1993)',
#   'Monty Python and the Holy Grail (1974)',
#   "Mr. Holland's Opus (1995)"],
#  886: ['In the Line of Fire (1993)',
#   'Indiana Jones and the Last Crusade (1989)',
#   'Truth About Cats & Dogs, The (1996)',
#   'Willy Wonka and the Chocolate Factory (1971)',
#   'Chasing Amy (1997)'],
#  887: ['Gone with the Wind (1939)',
#   'Michael (1996)',
#   'Seven (Se7en) (1995)',
#   "Mr. Holland's Opus (1995)",
#   'Space Jam (1996)'],
#  888: ['When Harry Met Sally... (1989)',
#   'Birdcage, The (1996)',
#   'Sense and Sensibility (1995)',
#   'Graduate, The (1967)',
#   'Postino, Il (1994)'],
#  889: ['Raising Arizona (1987)',
#   'Nikita (La Femme Nikita) (1990)',
#   'Field of Dreams (1989)',
#   'Crow, The (1994)',
#   'Aliens (1986)'],
#  890: ['Graduate, The (1967)',
#   'Bridge on the River Kwai, The (1957)',
#   'Bonnie and Clyde (1967)',
#   'Amadeus (1984)',
#   'Fantasia (1940)'],
#  891: ['Phenomenon (1996)',
#   'Toy Story (1995)',
#   'Executive Decision (1996)',
#   'Sense and Sensibility (1995)',
#   'Tin Cup (1996)'],
#  892: ['Great Escape, The (1963)',
#   'Liar Liar (1997)',
#   'Patton (1970)',
#   'Top Gun (1986)',
#   'Bridge on the River Kwai, The (1957)'],
#  893: ['Return of the Jedi (1983)',
#   'Twelve Monkeys (1995)',
#   'Broken Arrow (1996)',
#   'Raiders of the Lost Ark (1981)',
#   'Ransom (1996)'],
#  894: ['Cyrano de Bergerac (1990)',
#   'Ransom (1996)',
#   'Ridicule (1996)',
#   'Shall We Dance? (1996)',
#   'Sweet Hereafter, The (1997)'],
#  895: ['Jerry Maguire (1996)',
#   'Air Force One (1997)',
#   "Mr. Holland's Opus (1995)",
#   'Independence Day (ID4) (1996)',
#   'Men in Black (1997)'],
#  896: ['Reservoir Dogs (1992)',
#   'Right Stuff, The (1983)',
#   'Heathers (1989)',
#   'Great Escape, The (1963)',
#   'Casino (1995)'],
#  897: ["One Flew Over the Cuckoo's Nest (1975)",
#   'When Harry Met Sally... (1989)',
#   'Winnie the Pooh and the Blustery Day (1968)',
#   'To Kill a Mockingbird (1962)',
#   'Fantasia (1940)'],
#  898: ['Boogie Nights (1997)',
#   'Full Monty, The (1997)',
#   'Game, The (1997)',
#   "Devil's Advocate, The (1997)",
#   'Jackie Brown (1997)'],
#  899: ['Amadeus (1984)',
#   'Four Weddings and a Funeral (1994)',
#   'Dead Poets Society (1989)',
#   'Twister (1996)',
#   'Indiana Jones and the Last Crusade (1989)'],
#  900: ['Twelve Monkeys (1995)',
#   'Leaving Las Vegas (1995)',
#   "Mr. Holland's Opus (1995)",
#   'Toy Story (1995)',
#   'Primal Fear (1996)'],
#  901: ['Fugitive, The (1993)',
#   'Groundhog Day (1993)',
#   'Young Frankenstein (1974)',
#   'Hunt for Red October, The (1990)',
#   'True Lies (1994)'],
#  902: ['Raiders of the Lost Ark (1981)',
#   'Star Trek: First Contact (1996)',
#   "It's a Wonderful Life (1946)",
#   'Much Ado About Nothing (1993)',
#   "Singin' in the Rain (1952)"],
#  903: ['Monty Python and the Holy Grail (1974)',
#   '2001: A Space Odyssey (1968)',
#   'Hunt for Red October, The (1990)',
#   'Willy Wonka and the Chocolate Factory (1971)',
#   'Shining, The (1980)'],
#  904: ["Mr. Holland's Opus (1995)",
#   'Liar Liar (1997)',
#   'American President, The (1995)',
#   'Emma (1996)',
#   'Four Weddings and a Funeral (1994)'],
#  905: ['Leaving Las Vegas (1995)',
#   'Scream (1996)',
#   'English Patient, The (1996)',
#   'Sleepers (1996)',
#   'Dead Man Walking (1995)'],
#  906: ['Big Night (1996)',
#   'Primal Fear (1996)',
#   'Toy Story (1995)',
#   'People vs. Larry Flynt, The (1996)',
#   'Sense and Sensibility (1995)'],
#  907: ['Up Close and Personal (1996)',
#   'Broken Arrow (1996)',
#   'Eraser (1996)',
#   'Ghost and the Darkness, The (1996)',
#   'Twelve Monkeys (1995)'],
#  908: ['Wizard of Oz, The (1939)',
#   'Aliens (1986)',
#   'Babe (1995)',
#   "Singin' in the Rain (1952)",
#   'Citizen Kane (1941)'],
#  909: ['Like Water For Chocolate (Como agua para chocolate) (1992)',
#   'Room with a View, A (1986)',
#   'Conspiracy Theory (1997)',
#   'Big Night (1996)',
#   'Kolya (1996)'],
#  910: ['Leaving Las Vegas (1995)',
#   'Liar Liar (1997)',
#   'Twelve Monkeys (1995)',
#   'Godfather: Part II, The (1974)',
#   'Broken Arrow (1996)'],
#  911: ['Wizard of Oz, The (1939)',
#   'Terminator, The (1984)',
#   'Terminator 2: Judgment Day (1991)',
#   '2001: A Space Odyssey (1968)',
#   'Cinderella (1950)'],
#  912: ['Rear Window (1954)',
#   'Citizen Kane (1941)',
#   'North by Northwest (1959)',
#   'Silence of the Lambs, The (1991)',
#   'Annie Hall (1977)'],
#  913: ['Lion King, The (1994)',
#   '2001: A Space Odyssey (1968)',
#   "It's a Wonderful Life (1946)",
#   'Rosencrantz and Guildenstern Are Dead (1990)',
#   'Dances with Wolves (1990)'],
#  914: ['While You Were Sleeping (1995)',
#   'Dances with Wolves (1990)',
#   'I.Q. (1994)',
#   'Four Weddings and a Funeral (1994)',
#   'Little Women (1994)'],
#  915: ['Good Will Hunting (1997)',
#   'Full Monty, The (1997)',
#   'Boogie Nights (1997)',
#   'As Good As It Gets (1997)',
#   'Tomorrow Never Dies (1997)'],
#  916: ['Batman (1989)',
#   'Time to Kill, A (1996)',
#   'Pump Up the Volume (1990)',
#   'Benny & Joon (1993)',
#   'Eat Drink Man Woman (1994)'],
#  917: ["Mr. Holland's Opus (1995)",
#   'Lone Star (1996)',
#   'Truth About Cats & Dogs, The (1996)',
#   'Ransom (1996)',
#   'Phenomenon (1996)'],
#  918: ['Madness of King George, The (1994)',
#   'Postino, Il (1994)',
#   'Amadeus (1984)',
#   'My Left Foot (1989)',
#   'Unbearable Lightness of Being, The (1988)'],
#  919: ['Pulp Fiction (1994)',
#   'Beauty and the Beast (1991)',
#   'Graduate, The (1967)',
#   'Frighteners, The (1996)',
#   "One Flew Over the Cuckoo's Nest (1975)"],
#  920: ['Apt Pupil (1998)',
#   'Full Monty, The (1997)',
#   'Cop Land (1997)',
#   'Starship Troopers (1997)',
#   'Tomorrow Never Dies (1997)'],
#  921: ['Back to the Future (1985)',
#   'E.T. the Extra-Terrestrial (1982)',
#   'Twister (1996)',
#   'Air Force One (1997)',
#   'Eraser (1996)'],
#  922: ['Terminator 2: Judgment Day (1991)',
#   'Mrs. Doubtfire (1993)',
#   'E.T. the Extra-Terrestrial (1982)',
#   'Heavy Metal (1981)',
#   'Wizard of Oz, The (1939)'],
#  923: ['Face/Off (1997)',
#   'Long Kiss Goodnight, The (1996)',
#   'Twelve Monkeys (1995)',
#   'People vs. Larry Flynt, The (1996)',
#   'Courage Under Fire (1996)'],
#  924: ['Silence of the Lambs, The (1991)',
#   'Forrest Gump (1994)',
#   "Mr. Holland's Opus (1995)",
#   'Braveheart (1995)',
#   'Back to the Future (1985)'],
#  925: ['Jaws (1975)',
#   'Liar Liar (1997)',
#   'Birds, The (1963)',
#   'American Werewolf in London, An (1981)',
#   'Evil Dead II (1987)'],
#  926: ['In & Out (1997)',
#   'Chasing Amy (1997)',
#   'Seven Years in Tibet (1997)',
#   'Game, The (1997)',
#   'As Good As It Gets (1997)'],
#  927: ['Willy Wonka and the Chocolate Factory (1971)',
#   'Rock, The (1996)',
#   'Eraser (1996)',
#   'Cinderella (1950)',
#   'Princess Bride, The (1987)'],
#  928: ['Star Wars (1977)',
#   'Usual Suspects, The (1995)',
#   "Schindler's List (1993)",
#   'Wrong Trousers, The (1993)',
#   'Wizard of Oz, The (1939)'],
#  929: ['Return of the Jedi (1983)',
#   'Shawshank Redemption, The (1994)',
#   "One Flew Over the Cuckoo's Nest (1975)",
#   'Alien (1979)',
#   'Cool Hand Luke (1967)'],
#  930: ['Truth About Cats & Dogs, The (1996)',
#   'Secrets & Lies (1996)',
#   'Liar Liar (1997)',
#   'Birdcage, The (1996)',
#   "Mr. Holland's Opus (1995)"],
#  931: ['Secrets & Lies (1996)',
#   'Tomorrow Never Dies (1997)',
#   'Wings of the Dove, The (1997)',
#   'Dead Man Walking (1995)',
#   'Time to Kill, A (1996)'],
#  932: ['Dial M for Murder (1954)',
#   'East of Eden (1955)',
#   'It Happened One Night (1934)',
#   'Wizard of Oz, The (1939)',
#   'Cat on a Hot Tin Roof (1958)'],
#  933: ['Full Metal Jacket (1987)',
#   'Stand by Me (1986)',
#   'Amadeus (1984)',
#   'Young Frankenstein (1974)',
#   'Taxi Driver (1976)'],
#  934: ['Crying Game, The (1992)',
#   'Sting, The (1973)',
#   'Piano, The (1993)',
#   'True Lies (1994)',
#   'Manhattan (1979)'],
#  935: ['Truth About Cats & Dogs, The (1996)',
#   'Birdcage, The (1996)',
#   'Michael (1996)',
#   'Sense and Sensibility (1995)',
#   'Primal Fear (1996)'],
#  936: ['Donnie Brasco (1997)',
#   'Swingers (1996)',
#   'Scream (1996)',
#   "Mr. Holland's Opus (1995)",
#   'Private Parts (1997)'],
#  937: ['Godfather, The (1972)',
#   'Full Monty, The (1997)',
#   'Men in Black (1997)',
#   'Leaving Las Vegas (1995)',
#   'Return of the Jedi (1983)'],
#  938: ['Liar Liar (1997)',
#   'Time to Kill, A (1996)',
#   'Sabrina (1995)',
#   'Long Kiss Goodnight, The (1996)',
#   'Trainspotting (1996)'],
#  939: ['Truth About Cats & Dogs, The (1996)',
#   'Phenomenon (1996)',
#   'Time to Kill, A (1996)',
#   'Birdcage, The (1996)',
#   'Michael (1996)'],
#  940: ['Terminator, The (1984)',
#   'Indiana Jones and the Last Crusade (1989)',
#   'Brazil (1985)',
#   'Amistad (1997)',
#   'Harold and Maude (1971)'],
#  941: ['Star Wars (1977)',
#   'Willy Wonka and the Chocolate Factory (1971)',
#   'Jerry Maguire (1996)',
#   'Independence Day (ID4) (1996)',
#   'Wrong Trousers, The (1993)'],
#  942: ['Return of the Jedi (1983)',
#   'Tomorrow Never Dies (1997)',
#   'Dead Poets Society (1989)',
#   'My Fair Lady (1964)',
#   'Rear Window (1954)'],
#  943: ['Die Hard: With a Vengeance (1995)',
#   'Hunt for Red October, The (1990)',
#   'Glory (1989)',
#   'Desperado (1995)',
#   'Demolition Man (1993)']}
